# %% [markdown]
# <a href="https://colab.research.google.com/github/tanvirrahman0111/Simulation_and_Modeling_Lab_CSE_413/blob/main/SIM_Lab1_Md_Tanvir_Rahman_0432320005101116.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name**: Md. Tanvir Rahman
# **ID**: 0432320005101116
# **Course Code**: CSE 413
# **Course Title**: Simulation and Modeling Lab
# **Section**: 7B1
# **Assignment No**: 01

# %% [markdown]
# # Necessary Libraries

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Scalar &amp; Array Operations

# %%
# Sample scalar and array inputs
scalar = 3.7
arr = np.array([2,4,6,12,14,16])

# Trigonometric functions
sin_values = np.sin(arr)
cos_values = np.cos(arr)
tan_values = np.tan(arr)
asin_values = np.arcsin(np.clip(arr / np.max(arr), -1, 1))  # Normalized and Clipping for valid range [-1, 1]
acos_values = np.arccos(np.clip(arr / np.max(arr), -1, 1))
atan_values = np.arctan(arr)

# Exponential and logarithm
exp_values = np.exp(arr)
log_values = np.log(arr)  # Natural logarithm

# Absolute value and square root
abs_values = np.abs(arr)
sqrt_values = np.sqrt(arr)

# Remainder when divided by a scalar (e.g., 2)
rem_values = np.remainder(arr, 2)

# Rounding functions
round_values = np.round(arr)
floor_values = np.floor(arr)
ceil_values = np.ceil(arr)

# Display results
print("sin:", sin_values)
print("cos:", cos_values)
print("tan:", tan_values)
print("asin:", asin_values)
print("acos:", acos_values)
print("atan:", atan_values)
print("exp:", exp_values)
print("log:", log_values)
print("abs:", abs_values)
print("sqrt:", sqrt_values)
print("rem:", rem_values)
print("round:", round_values)
print("floor:", floor_values)
print("ceil:", ceil_values)
# Out:
# sin: [ 0.90929743 -0.7568025  -0.2794155  -0.53657292  0.99060736 -0.28790332]
# cos: [-0.41614684 -0.65364362  0.96017029  0.84385396  0.13673722 -0.95765948]
# tan: [-2.18503986  1.15782128 -0.29100619 -0.63585993  7.24460662  0.30063224]
# asin: [0.12532783 0.25268026 0.38439677 0.84806208 1.06543582 1.57079633]
# acos: [1.4454685  1.31811607 1.18639955 0.72273425 0.50536051 0.        ]
# atan: [1.10714872 1.32581766 1.40564765 1.48765509 1.49948886 1.50837752]
# exp: [7.38905610e+00 5.45981500e+01 4.03428793e+02 1.62754791e+05
#  1.20260428e+06 8.88611052e+06]
# log: [0.69314718 1.38629436 1.79175947 2.48490665 2.63905733 2.77258872]
# abs: [ 2  4  6 12 14 16]
# sqrt: [1.41421356 2.         2.44948974 3.46410162 3.74165739 4.        ]
# rem: [0 0 0 0 0 0]
# round: [ 2  4  6 12 14 16]
# floor: [ 2.  4.  6. 12. 14. 16.]
# ceil: [ 2.  4.  6. 12. 14. 16.]

# %% [markdown]
# # Create a 3×2 matrix with custom values

# %%
# Creating a 3x2 matrix
matrix = np.array([[3, 6], [5, 10], [10, 20]])

# Trigonometric functions
sin_values = np.sin(matrix)
cos_values = np.cos(matrix)
tan_values = np.tan(matrix)
asin_values = np.arcsin(np.clip(matrix / np.max(matrix), -1, 1))  # Clipping for valid range [-1, 1]
acos_values = np.arccos(np.clip(matrix / np.max(matrix), -1, 1))
atan_values = np.arctan(matrix)

# Exponential and logarithm
exp_values = np.exp(matrix)
log_values = np.log(matrix)  # Natural logarithm (log base e)

# Absolute value and square root
abs_values = np.abs(matrix)
sqrt_values = np.sqrt(matrix)

# Remainder when divided by a scalar (e.g., 2)
rem_values = np.remainder(matrix, 2)

# Rounding functions
round_values = np.round(matrix)
floor_values = np.floor(matrix)
ceil_values = np.ceil(matrix)

# Display results
print("Matrix:\n", matrix)
print("\nsin:\n", sin_values)
print("\ncos:\n", cos_values)
print("\ntan:\n", tan_values)
print("\nasine:\n", asin_values)
print("\nacosine:\n", acos_values)
print("\natangent:\n", atan_values)
print("\nexp:\n", exp_values)
print("\nlog (natural):\n", log_values)
print("\nabs:\n", abs_values)
print("\nsqrt:\n", sqrt_values)
print("\nrem (remainder when divided by 2):\n", rem_values)
print("\nround:\n", round_values)
print("\nfloor:\n", floor_values)
print("\nceil:\n", ceil_values)
# Out:
# Matrix:
#  [[ 3  6]
#  [ 5 10]
#  [10 20]]
#
# sin:
#  [[ 0.14112001 -0.2794155 ]
#  [-0.95892427 -0.54402111]
#  [-0.54402111  0.91294525]]
#
# cos:
#  [[-0.9899925   0.96017029]
#  [ 0.28366219 -0.83907153]
#  [-0.83907153  0.40808206]]
#
# tan:
#  [[-0.14254654 -0.29100619]
#  [-3.38051501  0.64836083]
#  [ 0.64836083  2.23716094]]
#
# asine:
#  [[0.15056827 0.30469265]
#  [0.25268026 0.52359878]
#  [0.52359878 1.57079633]]
#
# acosine:
#  [[1.42022805 1.26610367]
#  [1.31811607 1.04719755]
#  [1.04719755 0.        ]]
#
# atangent:
#  [[1.24904577 1.40564765]
#  [1.37340077 1.47112767]
#  [1.47112767 1.52083793]]
#
# exp:
#  [[2.00855369e+01 4.03428793e+02]
#  [1.48413159e+02 2.20264658e+04]
#  [2.20264658e+04 4.85165195e+08]]
#
# log (natural):
#  [[1.09861229 1.79175947]
#  [1.60943791 2.30258509]
#  [2.30258509 2.99573227]]
#
# abs:
#  [[ 3  6]
#  [ 5 10]
#  [10 20]]
#
# sqrt:
#  [[1.73205081 2.44948974]
#  [2.23606798 3.16227766]
#  [3.16227766 4.47213595]]
#
# rem (remainder when divided by 2):
#  [[1 0]
#  [1 0]
#  [0 0]]
#
# round:
#  [[ 3  6]
#  [ 5 10]
#  [10 20]]
#
# floor:
#  [[ 3.  6.]
#  [ 5. 10.]
#  [10. 20.]]
#
# ceil:
#  [[ 3.  6.]
#  [ 5. 10.]
#  [10. 20.]]

# %% [markdown]
# # Vector Operations on a 2×3 Matrix

# %%
# Sample vector (1D array)
vec = np.array([[5.3, 4.5,  6.8], [13.2, 14.7, 2.7]])

# 1. Maximum value and index of max element
max_value = np.max(vec)
max_index = np.argmax(vec)  # Index of max element

# 2. Minimum value and index of min element
min_value = np.min(vec)
min_index = np.argmin(vec)  # Index of min element

# 3. Length of the vector
vec_length = len(vec)  # Equivalent to MATLAB's length()

# 4. Sorting in row-wise descending order
sorted_row_desc = -np.sort(-vec, axis=1)

# Sorting in entire matrix descending order
sorted_flat_desc = np.sort(vec.flatten())[::-1]


# 5. Sum of elements
sum_values = np.sum(vec)

# 6. Product of elements
prod_values = np.prod(vec)

# 7. Median value
median_value = np.median(vec)

# 8. Mean value
mean_value = np.mean(vec)

# 9. Standard deviation
std_dev = np.std(vec)

# Display results
print("Max value:", max_value, "at index", max_index)
print("Min value:", min_value, "at index", min_index)
print("Length of vector:", vec_length)
print("Sorting in row-wise descending order:", sorted_row_desc)
print("Sorting in entire matrix descending order:", sorted_flat_desc)
print("Sum of elements:", sum_values)
print("Product of elements:", prod_values)
print("Median value:", median_value)
print("Mean value:", mean_value)
print("Standard deviation:", std_dev)
# Out:
# Max value: 14.7 at index 4
# Min value: 2.7 at index 5
# Length of vector: 2
# Sorting in row-wise descending order: [[ 6.8  5.3  4.5]
#  [14.7 13.2  2.7]]
# Sorting in entire matrix descending order: [14.7 13.2  6.8  5.3  4.5  2.7]
# Sum of elements: 47.2
# Product of elements: 84967.39943999998
# Median value: 6.05
# Mean value: 7.866666666666667
# Standard deviation: 4.488751373031133

# %% [markdown]
# # Visulalize matrix using seaborn.heatmap() or matplotlib.

# %%
# Vector matrix design
vec_matrix = np.array([[5.3, 4.5,  6.8], [13.2, 14.7, 2.7]])

# heatmap draw
plt.figure(figsize=(6,4))
sns.heatmap(vec_matrix, annot=True, cmap="Blues", fmt=".1f")
plt.title("Visualize of 2x3 Matrix")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# %% [markdown]
# # Visulalize matrix using seaborn.heatmap() or matplotlib with random numbers

# %%
# Random value matrix design
random_matrix = np.random.uniform(low=1.0, high=10.0, size=(2,3))

# heatmap draw
plt.figure(figsize=(6,4))
sns.heatmap(random_matrix, annot=True, cmap="Greens", fmt=".1f")
plt.title("Visualize of 2x3 Matrix")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()
